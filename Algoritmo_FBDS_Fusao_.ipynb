# %%
# Bibliotecas necessárias
import geopandas as gpd
import pandas as pd
import glob
import os
from pathlib import Path
import shutil

# %%
def find_shape_files(directory_path):
    list_shape_files = []
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith('.shp'):
                file_path = Path(root) / file
                list_shape_files.append(file_path)
    return list_shape_files

def find_infos(row, directory_path):
    my_url = row['url']
    url_path = Path(my_url)
    relative_path = url_path.relative_to(directory_path)

    parts = list(relative_path.parts)
    if len(parts) >= 3:
        sub_1, sub_2, nome_shape = parts[-3:]
    else:
        sub_1, sub_2, nome_shape = '', '', parts[-1]
    return (
        str(url_path),
        sub_1,
        sub_2,
        nome_shape
    )

# Função para encontrar o tipo de arquivo
def find_file_type(name):
    parts = name.split('_', maxsplit=2)
    if len(parts) < 3:
        return "Unknown"
    return parts[2].split('.')[0]

# Função para obter o caminho
def get_path_f(folder):
    states = {}
    for state_dir in os.listdir(folder):
        if os.path.isdir(os.path.join(folder, state_dir)):
            state_name = state_dir
            state_path = os.path.join(folder, state_dir)
            states[state_name] = state_path
    return states

# %%
from pathlib import Path
import pandas as pd
import geopandas as gpd

# Definindo os caminhos de entrada e saída como objetos Path
input_path = Path(r'D:\1_A_Projetos\BD\FBDS\RO\RO')
output_path = Path(r'D:\1_A_Projetos\BD\FBDS\RO\Ajuste')  # Certifique-se de que este caminho esteja correto

# %%
print(output_path)
# Out:
# D:\1_A_Projetos\BD\FBDS\RO\Ajuste

# %%
# Funções fictícias para simular o comportamento do código original
def find_shape_files(caminho):
    # Retorna uma lista de arquivos .shp no diretório (função fictícia para exemplo)
    return list(caminho.rglob("*.shp"))

def find_infos(row, caminho):
    # Simulação para a criação de colunas (função fictícia para exemplo)
    return [str(caminho), "sub1", "sub2", "nome_shape"]

def find_file_type(nome_shape):
    # Simulação para identificar o tipo do arquivo (função fictícia para exemplo)
    return "tipo_shape"

# Gerar dicionário de estados dinamicamente percorrendo subpastas
states_root = {estado.name: estado for estado in input_path.iterdir() if estado.is_dir()}

# Processando cada estado
for estado, caminho in states_root.items():
    print(f"Estado: {estado}, Caminho: {caminho}")
    
    # Encontre todos os arquivos .shp no diretório e suas subpastas
    list_shape_files = find_shape_files(caminho)
    
    # Crie DataFrame
    df = pd.DataFrame(list_shape_files, columns=['url'])
    
    # Crie colunas
    df[['path', 'sub_1', 'sub_2', 'nome_shape']] = df.apply(
        lambda row: pd.Series(find_infos(row, caminho)),
        axis=1,
    )
    df['nome_tipo'] = df['nome_shape'].apply(find_file_type)
    
    # Definir o caminho como objeto Path
    caminhoW = Path(caminho)
    
    # Listas de arquivos APP, HIDROGRAFIA e USO
    list_files_app = list(caminhoW.rglob('*APP/*APP.shp'))
    list_files_app_uso = list(caminhoW.rglob('*APP/*APP_USO.shp'))
    
    list_files_hidro_simples = list(caminhoW.rglob('*HIDROGRAFIA/*RIOS_SIMPLES.shp'))
    list_files_hidro_duplas = list(caminhoW.rglob('*HIDROGRAFIA/*RIOS_DUPLOS*.shp'))
    list_files_hidro_nascentes = list(caminhoW.rglob('*HIDROGRAFIA/*NASCENTE*.shp'))
    list_files_hidro_massa = list(caminhoW.rglob('*HIDROGRAFIA/*MASSA*_DAGUA*.shp'))
    
    list_files_uso = list(caminhoW.rglob('*USO/*USO*.shp'))
    
    # Dicionário de listas de dados
    dict_lists = {
        'app': list_files_app,
        'app_uso': list_files_app_uso,
        'hidro_simples': list_files_hidro_simples,
        'hidro_duplas': list_files_hidro_duplas,
        'hidro_nascentes': list_files_hidro_nascentes,
        'hidro_massa': list_files_hidro_massa,
        'uso': list_files_uso
    }
    
    # Loop sobre os itens do dicionário de listas de dados
    for k, v in dict_lists.items():
        if v:  # Certifica-se de que a lista não está vazia
            # Etapa 2: Junta todos os arquivos shapefiles em um único GeoDataFrame
            list_shp = [gpd.read_file(shp).to_crs(epsg=4326) for shp in v]
            gdf = gpd.GeoDataFrame(pd.concat(list_shp, ignore_index=True), crs="EPSG:4326")
            
            # Etapa 3: Salvar o GeoDataFrame como um arquivo .gpkg
            gdf.to_file(
                output_path / f'{estado}_{k}.gpkg',  # Corrigido com o uso do Path
                layer=f'{k}',
                driver='GPKG',
                overwrite=True  # Use o argumento correto 'overwrite' se necessário
            )
            print(f'Fim do {k}')
        
    # Liberar variáveis após cada iteração
    del list_shape_files, df, caminhoW, list_files_app, list_files_app_uso
    del list_files_hidro_simples, list_files_hidro_duplas, list_files_hidro_nascentes, list_files_hidro_massa
    del list_files_uso, dict_lists, list_shp, gdf
    
    # Fim da iteração do estado
    print(f'Fim da iteração para {estado}')
# Out:
# Estado: ALTA_FLORESTA_DOESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\ALTA_FLORESTA_DOESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para ALTA_FLORESTA_DOESTE
# Estado: ALTO_ALEGRE_DOS_PARECIS, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\ALTO_ALEGRE_DOS_PARECIS
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para ALTO_ALEGRE_DOS_PARECIS
# Estado: ALTO_PARAISO, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\ALTO_PARAISO
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para ALTO_PARAISO
# Estado: ALVORADA_DOESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\ALVORADA_DOESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para ALVORADA_DOESTE
# Estado: ARIQUEMES, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\ARIQUEMES
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para ARIQUEMES
# Estado: BURITIS, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\BURITIS
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para BURITIS
# Estado: CABIXI, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\CABIXI
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para CABIXI
# Estado: CACAULANDIA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\CACAULANDIA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para CACAULANDIA
# Estado: CACOAL, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\CACOAL
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para CACOAL
# Estado: CAMPO_NOVO_DE_RONDONIA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\CAMPO_NOVO_DE_RONDONIA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para CAMPO_NOVO_DE_RONDONIA
# Estado: CANDEIAS_DO_JAMARI, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\CANDEIAS_DO_JAMARI
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para CANDEIAS_DO_JAMARI
# Estado: CASTANHEIRAS, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\CASTANHEIRAS
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para CASTANHEIRAS
# Estado: CEREJEIRAS, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\CEREJEIRAS
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para CEREJEIRAS
# Estado: CHUPINGUAIA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\CHUPINGUAIA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para CHUPINGUAIA
# Estado: COLORADO_DO_OESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\COLORADO_DO_OESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para COLORADO_DO_OESTE
# Estado: CORUMBIARA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\CORUMBIARA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para CORUMBIARA
# Estado: COSTA_MARQUES, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\COSTA_MARQUES
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para COSTA_MARQUES
# Estado: CUJUBIM, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\CUJUBIM
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para CUJUBIM
# Estado: ESPIGAO_DOESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\ESPIGAO_DOESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para ESPIGAO_DOESTE
# Estado: GOVERNADOR_JORGE_TEIXEIRA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\GOVERNADOR_JORGE_TEIXEIRA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para GOVERNADOR_JORGE_TEIXEIRA
# Estado: GUAJARA_MIRIM, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\GUAJARA_MIRIM
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para GUAJARA_MIRIM
# Estado: ITAPUA_DO_OESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\ITAPUA_DO_OESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para ITAPUA_DO_OESTE
# Estado: JARU, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\JARU
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para JARU
# Estado: JI_PARANA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\JI_PARANA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para JI_PARANA
# Estado: MACHADINHO_DOESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\MACHADINHO_DOESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para MACHADINHO_DOESTE
# Estado: MINISTRO_ANDREAZZA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\MINISTRO_ANDREAZZA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para MINISTRO_ANDREAZZA
# Estado: MIRANTE_DA_SERRA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\MIRANTE_DA_SERRA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para MIRANTE_DA_SERRA
# Estado: MONTE_NEGRO, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\MONTE_NEGRO
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para MONTE_NEGRO
# Estado: NOVA_BRASILANDIA_DOESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\NOVA_BRASILANDIA_DOESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para NOVA_BRASILANDIA_DOESTE
# Estado: NOVA_MAMORE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\NOVA_MAMORE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para NOVA_MAMORE
# Estado: NOVA_UNIAO, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\NOVA_UNIAO
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para NOVA_UNIAO
# Estado: NOVO_HORIZONTE_DO_OESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\NOVO_HORIZONTE_DO_OESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para NOVO_HORIZONTE_DO_OESTE
# Estado: OURO_PRETO_DO_OESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\OURO_PRETO_DO_OESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para OURO_PRETO_DO_OESTE
# Estado: PARECIS, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\PARECIS
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para PARECIS
# Estado: PIMENTA_BUENO, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\PIMENTA_BUENO
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para PIMENTA_BUENO
# Estado: PIMENTEIRAS_DO_OESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\PIMENTEIRAS_DO_OESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para PIMENTEIRAS_DO_OESTE
# Estado: PORTO_VELHO, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\PORTO_VELHO
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para PORTO_VELHO
# Estado: PRESIDENTE_MEDICI, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\PRESIDENTE_MEDICI
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para PRESIDENTE_MEDICI
# Estado: PRIMAVERA_DE_RONDONIA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\PRIMAVERA_DE_RONDONIA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para PRIMAVERA_DE_RONDONIA
# Estado: RIO CRESPO, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\RIO CRESPO
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para RIO CRESPO
# Estado: RIO_CRESPO, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\RIO_CRESPO
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para RIO_CRESPO
# Estado: ROLIM_DE_MOURA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\ROLIM_DE_MOURA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para ROLIM_DE_MOURA
# Estado: SANTA_LUZIA_DOESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\SANTA_LUZIA_DOESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para SANTA_LUZIA_DOESTE
# Estado: SAO_FELIPE_DOESTE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\SAO_FELIPE_DOESTE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para SAO_FELIPE_DOESTE
# Estado: SAO_FRANCISCO_DO_GUAPORE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\SAO_FRANCISCO_DO_GUAPORE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para SAO_FRANCISCO_DO_GUAPORE
# Estado: SAO_MIGUEL_DO_GUAPORE, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\SAO_MIGUEL_DO_GUAPORE
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para SAO_MIGUEL_DO_GUAPORE
# Estado: SERINGUEIRAS, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\SERINGUEIRAS
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para SERINGUEIRAS
# Estado: TEIXEIROPOLIS, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\TEIXEIROPOLIS
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para TEIXEIROPOLIS
# Estado: THEOBROMA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\THEOBROMA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para THEOBROMA
# Estado: URUPA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\URUPA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para URUPA
# Estado: VALE_DO_ANARI, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\VALE_DO_ANARI
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para VALE_DO_ANARI
# Estado: VALE_DO_PARAISO, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\VALE_DO_PARAISO
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para VALE_DO_PARAISO
# Estado: VILHENA, Caminho: D:\1_A_Projetos\BD\FBDS\RO\RO\VILHENA
# Fim do app
# Fim do app_uso
# Fim do hidro_simples
# Fim do hidro_duplas
# Fim do hidro_nascentes
# Fim do hidro_massa
# Fim do uso
# Fim da iteração para VILHENA

# %%
import geopandas as gpd
import glob
import os
import pandas as pd

# %%
# Defina o diretório onde os arquivos .gpkg estão localizados
diretorio_origem = r"D:\1_A_Projetos\BD\FBDS\RO\Ajuste"

# Defina o diretório onde os arquivos combinados serão salvos
diretorio_destino = r"D:\1_A_Projetos\BD\FBDS\RO\Fusao"

# %%
# Verifique se o diretório de destino existe; caso contrário, crie-o
if not os.path.exists(diretorio_destino):
    os.makedirs(diretorio_destino)

# Listas de padrões para os diferentes tipos de arquivos que você quer combinar
tipos = ['app', 'app_uso', 'hidro_simples', 'hidro_duplas', 'hidro_nascentes', 'hidro_massa', 'uso']

# Loop para cada tipo de arquivo
for tipo in tipos:
    # Encontrar todos os arquivos que contêm o tipo no nome
    arquivos = glob.glob(os.path.join(diretorio_origem, f'*{tipo}*.gpkg'))
    
    # Verificar se foram encontrados arquivos para o tipo
    if len(arquivos) == 0:
        print(f"Nenhum arquivo encontrado para o tipo '{tipo}'")
        continue  # Pula para o próximo tipo

    print(f"Arquivos encontrados para '{tipo}': {arquivos}")
    
    # Lista para armazenar os geodataframes
    gdfs = []
    
    # Ler e armazenar cada arquivo na lista
    for arquivo in arquivos:
        gdf = gpd.read_file(arquivo)
        gdfs.append(gdf)
    
    # Verificar se a lista de GeoDataFrames não está vazia antes de concatenar
    if len(gdfs) > 0:
        # Concatenar todos os GeoDataFrames em um único
        gdf_total = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
        
        # Exportar para o diretório de destino
        gdf_total.to_file(os.path.join(diretorio_destino, f'RO_{tipo}.gpkg'), driver='GPKG')
        print(f"Arquivo RO_{tipo}.gpkg salvo com sucesso!")
    else:
        print(f"Nenhum GeoDataFrame válido encontrado para o tipo '{tipo}'.")

print("Processo concluído.")
# Out:
# Arquivos encontrados para 'app': ['D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTA_FLORESTA_DOESTE_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTA_FLORESTA_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_ALEGRE_DOS_PARECIS_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_ALEGRE_DOS_PARECIS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_PARAISO_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_PARAISO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALVORADA_DOESTE_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALVORADA_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ARIQUEMES_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ARIQUEMES_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\BURITIS_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\BURITIS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CABIXI_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CABIXI_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACAULANDIA_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACAULANDIA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACOAL_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACOAL_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CAMPO_NOVO_DE_RONDONIA_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CAMPO_NOVO_DE_RONDONIA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CANDEIAS_DO_JAMARI_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CANDEIAS_DO_JAMARI_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CASTANHEIRAS_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CASTANHEIRAS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CEREJEIRAS_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CEREJEIRAS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CHUPINGUAIA_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CHUPINGUAIA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COLORADO_DO_OESTE_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COLORADO_DO_OESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CORUMBIARA_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CORUMBIARA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COSTA_MARQUES_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COSTA_MARQUES_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CUJUBIM_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CUJUBIM_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ESPIGAO_DOESTE_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ESPIGAO_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GOVERNADOR_JORGE_TEIXEIRA_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GOVERNADOR_JORGE_TEIXEIRA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GUAJARA_MIRIM_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GUAJARA_MIRIM_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ITAPUA_DO_OESTE_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ITAPUA_DO_OESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JARU_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JARU_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JI_PARANA_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JI_PARANA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MACHADINHO_DOESTE_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MACHADINHO_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MINISTRO_ANDREAZZA_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MINISTRO_ANDREAZZA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MIRANTE_DA_SERRA_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MIRANTE_DA_SERRA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MONTE_NEGRO_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MONTE_NEGRO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_BRASILANDIA_DOESTE_app.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_BRASILANDIA_DOESTE_app ...
# Arquivo RO_app.gpkg salvo com sucesso!
# Arquivos encontrados para 'app_uso': ['D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTA_FLORESTA_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_ALEGRE_DOS_PARECIS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_PARAISO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALVORADA_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ARIQUEMES_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\BURITIS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CABIXI_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACAULANDIA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACOAL_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CAMPO_NOVO_DE_RONDONIA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CANDEIAS_DO_JAMARI_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CASTANHEIRAS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CEREJEIRAS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CHUPINGUAIA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COLORADO_DO_OESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CORUMBIARA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COSTA_MARQUES_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CUJUBIM_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ESPIGAO_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GOVERNADOR_JORGE_TEIXEIRA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GUAJARA_MIRIM_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ITAPUA_DO_OESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JARU_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JI_PARANA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MACHADINHO_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MINISTRO_ANDREAZZA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MIRANTE_DA_SERRA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MONTE_NEGRO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_BRASILANDIA_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_MAMORE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_UNIAO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVO_HORIZONTE_DO_OESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\OURO_PRETO_DO_OESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PARECIS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PIMENTA_BUENO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PIMENTEIRAS_DO_OESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PORTO_VELHO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PRESIDENTE_MEDICI_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PRIMAVERA_DE_RONDONIA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\RIO CRESPO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\RIO_CRESPO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ROLIM_DE_MOURA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SANTA_LUZIA_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_FELIPE_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_FRANCISCO_DO_GUAPORE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_MIGUEL_DO_GUAPORE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SERINGUEIRAS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\TEIXEIROPOLIS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\THEOBROMA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\URUPA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\VALE_DO_ANARI_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\VALE_DO_PARAISO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\VILHENA_app_uso.gpkg']
# Arquivo RO_app_uso.gpkg salvo com sucesso!
# Arquivos encontrados para 'hidro_simples': ['D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTA_FLORESTA_DOESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_ALEGRE_DOS_PARECIS_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_PARAISO_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALVORADA_DOESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ARIQUEMES_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\BURITIS_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CABIXI_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACAULANDIA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACOAL_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CAMPO_NOVO_DE_RONDONIA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CANDEIAS_DO_JAMARI_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CASTANHEIRAS_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CEREJEIRAS_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CHUPINGUAIA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COLORADO_DO_OESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CORUMBIARA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COSTA_MARQUES_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CUJUBIM_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ESPIGAO_DOESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GOVERNADOR_JORGE_TEIXEIRA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GUAJARA_MIRIM_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ITAPUA_DO_OESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JARU_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JI_PARANA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MACHADINHO_DOESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MINISTRO_ANDREAZZA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MIRANTE_DA_SERRA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MONTE_NEGRO_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_BRASILANDIA_DOESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_MAMORE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_UNIAO_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVO_HORIZONTE_DO_OESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\OURO_PRETO_DO_OESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PARECIS_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PIMENTA_BUENO_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PIMENTEIRAS_DO_OESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PORTO_VELHO_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PRESIDENTE_MEDICI_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PRIMAVERA_DE_RONDONIA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\RIO CRESPO_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\RIO_CRESPO_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ROLIM_DE_MOURA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SANTA_LUZIA_DOESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_FELIPE_DOESTE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_FRANCISCO_DO_GUAPORE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_MIGUEL_DO_GUAPORE_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SERINGUEIRAS_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\TEIXEIROPOLIS_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\THEOBROMA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\URUPA_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\VALE_DO_ANARI_hidro_simples.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO ...
# Arquivo RO_hidro_simples.gpkg salvo com sucesso!
# Arquivos encontrados para 'hidro_duplas': ['D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTA_FLORESTA_DOESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_ALEGRE_DOS_PARECIS_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_PARAISO_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALVORADA_DOESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ARIQUEMES_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\BURITIS_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CABIXI_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACAULANDIA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACOAL_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CAMPO_NOVO_DE_RONDONIA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CANDEIAS_DO_JAMARI_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CASTANHEIRAS_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CEREJEIRAS_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CHUPINGUAIA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COLORADO_DO_OESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CORUMBIARA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COSTA_MARQUES_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CUJUBIM_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ESPIGAO_DOESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GOVERNADOR_JORGE_TEIXEIRA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GUAJARA_MIRIM_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ITAPUA_DO_OESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JARU_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JI_PARANA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MACHADINHO_DOESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MINISTRO_ANDREAZZA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MIRANTE_DA_SERRA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MONTE_NEGRO_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_BRASILANDIA_DOESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_MAMORE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_UNIAO_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVO_HORIZONTE_DO_OESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\OURO_PRETO_DO_OESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PARECIS_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PIMENTA_BUENO_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PIMENTEIRAS_DO_OESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PORTO_VELHO_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PRESIDENTE_MEDICI_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PRIMAVERA_DE_RONDONIA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\RIO CRESPO_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\RIO_CRESPO_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ROLIM_DE_MOURA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SANTA_LUZIA_DOESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_FELIPE_DOESTE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_FRANCISCO_DO_GUAPORE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_MIGUEL_DO_GUAPORE_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SERINGUEIRAS_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\TEIXEIROPOLIS_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\THEOBROMA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\URUPA_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\VALE_DO_ANARI_hidro_duplas.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\VALE_DO_PARAISO_hidro_duplas.gpkg', 'D:\\1 ...
# Arquivo RO_hidro_duplas.gpkg salvo com sucesso!
# Arquivos encontrados para 'hidro_nascentes': ['D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTA_FLORESTA_DOESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_ALEGRE_DOS_PARECIS_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_PARAISO_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALVORADA_DOESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ARIQUEMES_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\BURITIS_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CABIXI_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACAULANDIA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACOAL_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CAMPO_NOVO_DE_RONDONIA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CANDEIAS_DO_JAMARI_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CASTANHEIRAS_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CEREJEIRAS_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CHUPINGUAIA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COLORADO_DO_OESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CORUMBIARA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COSTA_MARQUES_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CUJUBIM_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ESPIGAO_DOESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GOVERNADOR_JORGE_TEIXEIRA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GUAJARA_MIRIM_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ITAPUA_DO_OESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JARU_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JI_PARANA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MACHADINHO_DOESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MINISTRO_ANDREAZZA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MIRANTE_DA_SERRA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MONTE_NEGRO_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_BRASILANDIA_DOESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_MAMORE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_UNIAO_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVO_HORIZONTE_DO_OESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\OURO_PRETO_DO_OESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PARECIS_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PIMENTA_BUENO_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PIMENTEIRAS_DO_OESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PORTO_VELHO_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PRESIDENTE_MEDICI_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PRIMAVERA_DE_RONDONIA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\RIO CRESPO_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\RIO_CRESPO_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ROLIM_DE_MOURA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SANTA_LUZIA_DOESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_FELIPE_DOESTE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_FRANCISCO_DO_GUAPORE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_MIGUEL_DO_GUAPORE_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SERINGUEIRAS_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\TEIXEIROPOLIS_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\THEOBROMA_hidro_nascentes.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\URUPA_hidro_nascentes.gpkg', 'D:\\ ...
# Arquivo RO_hidro_nascentes.gpkg salvo com sucesso!
# Arquivos encontrados para 'hidro_massa': ['D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTA_FLORESTA_DOESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_ALEGRE_DOS_PARECIS_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_PARAISO_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALVORADA_DOESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ARIQUEMES_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\BURITIS_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CABIXI_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACAULANDIA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACOAL_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CAMPO_NOVO_DE_RONDONIA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CANDEIAS_DO_JAMARI_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CASTANHEIRAS_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CEREJEIRAS_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CHUPINGUAIA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COLORADO_DO_OESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CORUMBIARA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COSTA_MARQUES_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CUJUBIM_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ESPIGAO_DOESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GOVERNADOR_JORGE_TEIXEIRA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GUAJARA_MIRIM_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ITAPUA_DO_OESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JARU_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JI_PARANA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MACHADINHO_DOESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MINISTRO_ANDREAZZA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MIRANTE_DA_SERRA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MONTE_NEGRO_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_BRASILANDIA_DOESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_MAMORE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_UNIAO_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVO_HORIZONTE_DO_OESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\OURO_PRETO_DO_OESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PARECIS_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PIMENTA_BUENO_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PIMENTEIRAS_DO_OESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PORTO_VELHO_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PRESIDENTE_MEDICI_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\PRIMAVERA_DE_RONDONIA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\RIO CRESPO_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\RIO_CRESPO_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ROLIM_DE_MOURA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SANTA_LUZIA_DOESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_FELIPE_DOESTE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_FRANCISCO_DO_GUAPORE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SAO_MIGUEL_DO_GUAPORE_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\SERINGUEIRAS_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\TEIXEIROPOLIS_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\THEOBROMA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\URUPA_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\VALE_DO_ANARI_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\VALE_DO_PARAISO_hidro_massa.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\VILHENA_hidro_mass ...
# Arquivo RO_hidro_massa.gpkg salvo com sucesso!
# Arquivos encontrados para 'uso': ['D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTA_FLORESTA_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTA_FLORESTA_DOESTE_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_ALEGRE_DOS_PARECIS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_ALEGRE_DOS_PARECIS_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_PARAISO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALTO_PARAISO_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALVORADA_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ALVORADA_DOESTE_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ARIQUEMES_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ARIQUEMES_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\BURITIS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\BURITIS_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CABIXI_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CABIXI_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACAULANDIA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACAULANDIA_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACOAL_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CACOAL_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CAMPO_NOVO_DE_RONDONIA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CAMPO_NOVO_DE_RONDONIA_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CANDEIAS_DO_JAMARI_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CANDEIAS_DO_JAMARI_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CASTANHEIRAS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CASTANHEIRAS_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CEREJEIRAS_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CEREJEIRAS_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CHUPINGUAIA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CHUPINGUAIA_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COLORADO_DO_OESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COLORADO_DO_OESTE_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CORUMBIARA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CORUMBIARA_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COSTA_MARQUES_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\COSTA_MARQUES_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CUJUBIM_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\CUJUBIM_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ESPIGAO_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ESPIGAO_DOESTE_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GOVERNADOR_JORGE_TEIXEIRA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GOVERNADOR_JORGE_TEIXEIRA_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GUAJARA_MIRIM_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\GUAJARA_MIRIM_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ITAPUA_DO_OESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\ITAPUA_DO_OESTE_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JARU_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JARU_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JI_PARANA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\JI_PARANA_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MACHADINHO_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MACHADINHO_DOESTE_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MINISTRO_ANDREAZZA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MINISTRO_ANDREAZZA_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MIRANTE_DA_SERRA_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MIRANTE_DA_SERRA_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MONTE_NEGRO_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\MONTE_NEGRO_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_BRASILANDIA_DOESTE_app_uso.gpkg', 'D:\\1_A_Projetos\\BD\\FBDS\\RO\\Ajuste\\NOVA_BRASILANDIA_DOESTE ...
# Arquivo RO_uso.gpkg salvo com sucesso!
# Processo concluído.
